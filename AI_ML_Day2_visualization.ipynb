# %% [markdown]
# <a href="https://colab.research.google.com/github/kaj5rhino/AIML-Training_Jyothi/blob/main/AI_ML_Day2_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %%
x=np.random.random(100)
y=np.random.normal(size=100)

# %%
print(x)
# Out:
# [0.61409615 0.45343238 0.64460822 0.34392093 0.21740473 0.59093216
#  0.4908602  0.54216417 0.29267164 0.28113333 0.91411984 0.78286633
#  0.15159829 0.47670885 0.11633914 0.79617715 0.31449051 0.27641893
#  0.88933245 0.60431629 0.02819296 0.70655571 0.41796395 0.65817472
#  0.39167137 0.94635388 0.95873513 0.20058761 0.702966   0.51923367
#  0.56198485 0.92344942 0.80961651 0.88424198 0.270151   0.89013737
#  0.91325814 0.9518164  0.22563975 0.93977147 0.63043393 0.3643017
#  0.9527901  0.37515376 0.44548272 0.3233788  0.22578951 0.06741736
#  0.91451219 0.19624385 0.16043254 0.13902777 0.05423553 0.78144588
#  0.44329219 0.32991987 0.8565202  0.83680475 0.94615104 0.07672447
#  0.14311257 0.89513818 0.82316068 0.12317135 0.26756016 0.59782474
#  0.89789828 0.90099272 0.21762621 0.63590782 0.55008666 0.01703022
#  0.06509163 0.88788326 0.18565747 0.99587135 0.21766537 0.07292974
#  0.96670639 0.9507834  0.14249492 0.06543412 0.98536862 0.04868856
#  0.31469442 0.27136111 0.93193149 0.26914876 0.43604438 0.35820918
#  0.55837063 0.38342798 0.54035579 0.14044947 0.91669792 0.0765386
#  0.82011913 0.70084906 0.33780394 0.69339315]

# %%
plt.hist(x,bins=20)
# Out:
# (array([ 1.,  0.,  5.,  3.,  2.,  6.,  5., 15.,  8., 14.,  4., 11.,  8.,
#          7.,  5.,  3.,  2.,  0.,  0.,  1.]),
#  array([-2.59197103, -2.31474086, -2.03751068, -1.76028051, -1.48305033,
#         -1.20582016, -0.92858998, -0.65135981, -0.37412963, -0.09689945,
#          0.18033072,  0.4575609 ,  0.73479107,  1.01202125,  1.28925142,
#          1.5664816 ,  1.84371177,  2.12094195,  2.39817212,  2.6754023 ,
#          2.95263248]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(y,bins=20,color='red')
# Out:
# (array([ 1.,  0.,  5.,  3.,  2.,  6.,  5., 15.,  8., 14.,  4., 11.,  8.,
#          7.,  5.,  3.,  2.,  0.,  0.,  1.]),
#  array([-2.59197103, -2.31474086, -2.03751068, -1.76028051, -1.48305033,
#         -1.20582016, -0.92858998, -0.65135981, -0.37412963, -0.09689945,
#          0.18033072,  0.4575609 ,  0.73479107,  1.01202125,  1.28925142,
#          1.5664816 ,  1.84371177,  2.12094195,  2.39817212,  2.6754023 ,
#          2.95263248]),
#  <BarContainer object of 20 artists>)

# %%
sns.histplot(y,bins=20,kde=True);

# %%
sns.kdeplot(y,color='green',fill=True);

# %%
sns.kdeplot(y,color='green',fill=True);sns.kdeplot(x,color='magenta',fill=True);

# %%
plt.subplot(121)
sns.kdeplot(y,color='green',fill=True);
plt.subplot(122)
sns.kdeplot(x,color='magenta',fill=True);

# %%
plt.subplot(211)
sns.kdeplot(y,color='green',fill=True);
plt.subplot(212)
sns.kdeplot(x,color='magenta',fill=True);

# %%
tips_df=sns.load_dataset('tips')

# %%
print(tips_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None

# %%
print (tips_df.sample(10))
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 149        7.51  2.00    Male     No  Thur   Lunch     2
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 139       13.16  2.75  Female     No  Thur   Lunch     2
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2
# 27        12.69  2.00    Male     No   Sat  Dinner     2
# 117       10.65  1.50  Female     No  Thur   Lunch     2
# 31        18.35  2.50    Male     No   Sat  Dinner     4
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4
# 90        28.97  3.00    Male    Yes   Fri  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4

# %%
print (tips_df.head(10))
print (tips_df.tail(10))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2
#      total_bill   tip     sex smoker   day    time  size
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips_df.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.histplot(tips_df.total_bill,color='blue',bins=20)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(tips_df.tip,color='blue',bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(tips_df.tip/tips_df.total_bill,color='yellow',bins=20)
# Out:
# <Axes: ylabel='Count'>

# %%
tt=tips_df.tip/tips_df.total_bill
tips_df[tt>0.4]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2

# %%
tips_df.count()
tips_df[tips_df.day=='Sun'].count()
tips_df[tips_df.day=='Sun']
tips_df[tips_df.day=='Sun']['day']
tips_df[tips_df.day=='Sun']['day'].count()
# Out:
# 76

# %%
tips_series=tips_df.groupby('day')['day'].count()
sns.histplot(x=tips_series.index,y=tips_series.values)
# Out:
# <Axes: xlabel='day'>

# %%
sns.relplot(data=tips_df,x='total_bill',y='tip')

# %%
sns.regplot(data=tips_df,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data=tips_df,x='total_bill',y='tip')

# %%
sns.lmplot(data=tips_df[tips_df.sex=='Male'],x='total_bill',y='tip');
sns.lmplot(data=tips_df[tips_df.sex=='Female'],x='total_bill',y='tip');

# %%
sns.lmplot(data=tips_df,x='total_bill',y='tip',hue='sex');

# %%
sns.lmplot(data=tips_df,x='total_bill',y='tip',hue='day');

# %%
sns.lmplot(data=tips_df,x='total_bill',y='tip',hue='day',col='smoker');

# %%
sns.lmplot(data=tips_df,x='total_bill',y='tip',hue='day',col='smoker',row='sex');

# %%
sns.pairplot(tips_df)

# %%
##composition of data
plt.pie(tips_series,labels=tips_series.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7d5883ee6470>,
#   <matplotlib.patches.Wedge at 0x7d5883ee6380>,
#   <matplotlib.patches.Wedge at 0x7d5883ee6d40>,
#   <matplotlib.patches.Wedge at 0x7d5883ee71c0>],
#  [Text(0.7677385823341432, 0.7877673953620831, 'Thur'),
#   Text(-0.29381052431802407, 1.060035554026358, 'Fri'),
#   Text(-1.0977213807589423, -0.07076560057458063, 'Sat'),
#   Text(0.6140679625556313, -0.9126448035039567, 'Sun')])

# %%
plt.pie(tips_series,labels=tips_series.index,autopct='%0.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7d5883d1aa10>,
#   <matplotlib.patches.Wedge at 0x7d5883d1ab30>,
#   <matplotlib.patches.Wedge at 0x7d5883d1b880>,
#   <matplotlib.patches.Wedge at 0x7d5883d186a0>],
#  [Text(0.7677385823341432, 0.7877673953620831, 'Thur'),
#   Text(-0.29381052431802407, 1.060035554026358, 'Fri'),
#   Text(-1.0977213807589423, -0.07076560057458063, 'Sat'),
#   Text(0.6140679625556313, -0.9126448035039567, 'Sun')],
#  [Text(0.4187664994549871, 0.4296913065611362, '25.41%'),
#   Text(-0.16026028599164946, 0.5782012112871043, '7.79%'),
#   Text(-0.5987571167776049, -0.038599418495225794, '35.66%'),
#   Text(0.3349461613939807, -0.4978062564567036, '31.15%')])

# %%
plt.pie(tips_series,labels=tips_series.index,autopct='%0.2f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7d5883cf52d0>,
#   <matplotlib.patches.Wedge at 0x7d5883cf51e0>,
#   <matplotlib.patches.Wedge at 0x7d5883cf6440>,
#   <matplotlib.patches.Wedge at 0x7d5883cf6d10>],
#  [Text(0.7677385823341432, 0.7877673953620831, 'Thur'),
#   Text(-0.29381052431802407, 1.060035554026358, 'Fri'),
#   Text(-1.0977213807589423, -0.07076560057458063, 'Sat'),
#   Text(0.6140679625556313, -0.9126448035039567, 'Sun')],
#  [Text(0.4187664994549871, 0.4296913065611362, '25.41%'),
#   Text(-0.16026028599164946, 0.5782012112871043, '7.79%'),
#   Text(-0.5987571167776049, -0.038599418495225794, '35.66%'),
#   Text(0.3349461613939807, -0.4978062564567036, '31.15%')])

# %%
plt.pie(tips_series,labels=tips_series.index,autopct='%0.2f%%',shadow=True,explode=[0,1,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x7d5884419b40>,
#   <matplotlib.patches.Wedge at 0x7d5884419a50>,
#   <matplotlib.patches.Wedge at 0x7d588441acb0>,
#   <matplotlib.patches.Wedge at 0x7d588441b580>],
#  [Text(0.7677385823341432, 0.7877673953620831, 'Thur'),
#   Text(-0.5609110009707732, 2.023704239504865, 'Fri'),
#   Text(-1.0977213807589423, -0.07076560057458063, 'Sat'),
#   Text(0.6140679625556313, -0.9126448035039567, 'Sun')],
#  [Text(0.4187664994549871, 0.4296913065611362, '25.41%'),
#   Text(-0.4273607626443986, 1.5418698967656117, '7.79%'),
#   Text(-0.5987571167776049, -0.038599418495225794, '35.66%'),
#   Text(0.3349461613939807, -0.4978062564567036, '31.15%')])

# %%
plt.pie(tips_series,labels=tips_series.index,autopct='%0.2f%%',shadow=True,wedgeprops=dict(width=0.25))
# Out:
# ([<matplotlib.patches.Wedge at 0x7d5883cea1d0>,
#   <matplotlib.patches.Wedge at 0x7d5883ceb550>,
#   <matplotlib.patches.Wedge at 0x7d58843eae60>,
#   <matplotlib.patches.Wedge at 0x7d58843eb730>],
#  [Text(0.7677385823341432, 0.7877673953620831, 'Thur'),
#   Text(-0.29381052431802407, 1.060035554026358, 'Fri'),
#   Text(-1.0977213807589423, -0.07076560057458063, 'Sat'),
#   Text(0.6140679625556313, -0.9126448035039567, 'Sun')],
#  [Text(0.4187664994549871, 0.4296913065611362, '25.41%'),
#   Text(-0.16026028599164946, 0.5782012112871043, '7.79%'),
#   Text(-0.5987571167776049, -0.038599418495225794, '35.66%'),
#   Text(0.3349461613939807, -0.4978062564567036, '31.15%')])

# %%
plt.pie(tips_series,labels=tips_series.index,autopct='%0.2f%%',shadow=True,wedgeprops=dict(width=0.25))
